# %%
from sklearn.metrics import roc_auc_score
import numpy as np
from scipy.stats import rankdata
import sys
import pandas as pd 

def compute_auc(groups, true, false, rank = False, write = False):
    aucs = []
    y_ranks = []
    for group in groups:
        y_pred = np.concatenate((true[group], false[group]))
        y_true = np.concatenate((np.ones(len(true[group])), np.zeros(len(false[group]))))
        auc = roc_auc_score(y_true, y_pred)
        aucs.append(auc)
        if rank == True:
            y_ranks = np.concatenate((y_ranks, rankdata(-y_pred)[:len(true[group])]))
    if rank == True:
        return np.mean(aucs), y_ranks
    return np.mean(aucs)

def conf_interval(data):
    mean = np.mean(data)
    var = np.var(data)
    interval = 1.96 * np.sqrt(var/len(data))
    print(mean, mean-interval, mean+interval)

write = False
metrics = []
path = 'preds_joint_t333761_v333760'
for fold in ["species", "family"]:
    families, taxa, vps = set(), set(), set()
    if "2697049" not in path:
        family = '<http://purl.obolibrary.org/obo/NCBITaxon_test>'
        taxon = '<http://purl.obolibrary.org/obo/NCBITaxon_333761>'
        families.add(family)
        taxa.add(taxon)
        with open('data/train_1000.txt', 'r') as f:
            next(f)
            for line in f:
                items = line.strip().split()
                if taxon == '<http://purl.obolibrary.org/obo/NCBITaxon_' + items[2] + '>':
                    vp = items[1]
                    vps.add(vp)
    else:
        families.add('<http://purl.obolibrary.org/obo/NCBITaxon_test>')
        taxa.add('<http://purl.obolibrary.org/obo/NCBITaxon_2697049>')
        dfs_interaction = pd.read_excel('data/media-6.xlsx', sheet_name = None, skiprows=1)
        for index, row in dfs_interaction["Sheet1"].iterrows():
            vp = row['Bait']
            vps.add(vp)

    print(len(families), len(taxa), len(vps))

    family_aucss = []
    taxon_aucss = []
    vp_aucss = []
    mean_ranks = []

    count = 0
    for i in range(5):
        print('Going through prediction file ', count)
        count += 1

        family_true, family_false, taxon_true, taxon_false, vp_true, vp_false = {}, {}, {}, {}, {}, {}
        for family in families:
            family_true[family] = []
            family_false[family] = []
        for taxon in taxa:
            taxon_true[taxon] = []
            taxon_false[taxon] = []
        for vp in vps:
            vp_true[vp] = []
            vp_false[vp] = []

        with open(f"{path}_{fold}_{i}.txt", 'r') as f:
            for line in f:
                items = line.strip().split("\t")
                vp = items[0]
                taxon = items[2]
                family = items[3]
                label = items[5]
                score = float(items[4])
                if label == "True":
                    family_true[family].append(score)
                    taxon_true[taxon].append(score)
                    vp_true[vp].append(score)
                elif label == "False":
                    family_false[family].append(score)
                    taxon_false[taxon].append(score)
                    vp_false[vp].append(score)

        family_aucss.append(compute_auc(families, family_true, family_false, write=write))
        taxon_aucss.append(compute_auc(taxa, taxon_true, taxon_false))
        vp_auc, y_ranks = compute_auc(vps, vp_true, vp_false, rank=True)
        vp_aucss.append(vp_auc)
        mean_ranks.append(np.mean(y_ranks))
    
    conf_interval(taxon_aucss)
    conf_interval(vp_aucss)
    print(np.mean(mean_ranks))
    metrics.append(np.mean(taxon_aucss))
    metrics.append(np.mean(vp_aucss))
    metrics.append(np.mean(mean_ranks))
print(metrics[0] - metrics[3], metrics[1] - metrics[4], metrics[2] - metrics[5])
# Out:
# 1 1 8
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4
# 0.8009371169184908 0.7707694099424234 0.8311048238945582
# 0.8897825641963756 0.8723428636361557 0.9072222647565955
# 3240.352808988764
# 1 1 8
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4
# 0.7474135105457334 0.7162406319543256 0.7785863891371411
# 0.8201179343571828 0.794549691511215 0.8456861772031506
# 4157.402247191012
# 0.05352360637275744 0.06966462983919275 -917.049438202248

# %%
family2order = {'<http://purl.obolibrary.org/obo/NCBITaxon_10240>': '12',
 '<http://purl.obolibrary.org/obo/NCBITaxon_10292>': '8',
 '<http://purl.obolibrary.org/obo/NCBITaxon_10508>': '10',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11050>': '11',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11158>': '6',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11266>': '3',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11308>': '4',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11632>': '7',
 '<http://purl.obolibrary.org/obo/NCBITaxon_151340>': '14',
 '<http://purl.obolibrary.org/obo/NCBITaxon_151341>': '9',
 '<http://purl.obolibrary.org/obo/NCBITaxon_10780>': '2',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11244>': '5',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11617>': '1',
 '<http://purl.obolibrary.org/obo/NCBITaxon_10404>': "13"
}

# %%
family2name = {'<http://purl.obolibrary.org/obo/NCBITaxon_10240>': 'Poxviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_10292>': 'Herpesviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_10508>': 'Adenoviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11050>': 'Flaviviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11158>': 'Paramyxoviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11266>': 'Filoviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11308>': 'Orthomyxoviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11632>': 'Retroviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_151340>': 'Papillomaviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_151341>': 'Polyomaviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_10780>': 'Parvoviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11244>': 'Pneumoviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_11617>': 'Arenaviridae',
 '<http://purl.obolibrary.org/obo/NCBITaxon_10404>': "Hepadnaviridae"
}

from sklearn.metrics import roc_auc_score
import numpy as np
from scipy.stats import rankdata
import sys
import pandas as pd 

write = True
if write == True:
    auc_file = open('familywise_jointseq.txt', 'w')
    auc_file.close()
    
def compute_auc(groups, true, false, rank = False, write = False, option = None):
    aucs = []
    y_ranks = []
    for group in groups:
        y_pred = np.concatenate((true[group], false[group]))
        y_true = np.concatenate((np.ones(len(true[group])), np.zeros(len(false[group]))))
        auc = roc_auc_score(y_true, y_pred)
        aucs.append(auc)
        if write == True:
            with open('familywise_jointseq.txt', 'a+') as f:
                f.write("%s\t%s\t%f\t%d\t%s\n" % (family2name[group], option, auc, len(true[group]), family2order[group]))
        if rank == True:
            y_ranks = np.concatenate((y_ranks, rankdata(-y_pred)[:len(true[group])]))
    if rank == True:
        return np.mean(aucs), y_ranks
    return np.mean(aucs)

for option in ["joint", "seq"]:
        path = f'preds/preds_{option}_'
        families, taxa, vps = set(), set(), set()
        with open('data/train_1000.txt', 'r') as f:
            next(f)
            for line in f:
                items = line.strip().split()
                family = '<http://purl.obolibrary.org/obo/NCBITaxon_' + items[3] + '>'
                taxon = '<http://purl.obolibrary.org/obo/NCBITaxon_' + items[2] + '>'
                vp = items[1]
                families.add(family)
                vps.add(vp)
                taxa.add(taxon)

        print(len(families), len(taxa), len(vps))

        family_aucss = []
        taxon_aucss = []
        vp_aucss = []
        mean_ranks = []

        count = 0
        for i in range(5):
            print('Going through prediction file ', count)
            count += 1

            family_true, family_false, taxon_true, taxon_false, vp_true, vp_false = {}, {}, {}, {}, {}, {}
            for family in families:
                family_true[family] = []
                family_false[family] = []
            for taxon in taxa:
                taxon_true[taxon] = []
                taxon_false[taxon] = []
            for vp in vps:
                vp_true[vp] = []
                vp_false[vp] = []

            with open(f"{path}{i}.txt", 'r') as f:
                for line in f:
                    items = line.strip().split("\t")
                    vp = items[0]
                    taxon = items[2]
                    family = items[3]
                    label = items[5]
                    score = float(items[4])
                    if label == "True":
                        family_true[family].append(score)
                        taxon_true[taxon].append(score)
                        vp_true[vp].append(score)
                    elif label == "False":
                        family_false[family].append(score)
                        taxon_false[taxon].append(score)
                        vp_false[vp].append(score)

            family_aucss.append(compute_auc(families, family_true, family_false, option=option, write=write))
            taxon_aucss.append(compute_auc(taxa, taxon_true, taxon_false))
            vp_auc, y_ranks = compute_auc(vps, vp_true, vp_false, rank=True)
            vp_aucss.append(vp_auc)
            mean_ranks.append(np.mean(y_ranks))

        def conf_interval(data):
            mean = np.mean(data)
            var = np.var(data)
            interval = 1.96 * np.sqrt(var/len(data))
            print(mean, mean-interval, mean+interval)

        conf_interval(vp_aucss)
        conf_interval(taxon_aucss)
        conf_interval(family_aucss)
        print(np.mean(mean_ranks))
        print(np.median(mean_ranks))
# Out:
# 14 292 1066
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4
# 0.8008372513658255 0.7971775438260802 0.8044969589055708
# 0.8287867609612121 0.8220588890408382 0.8355146328815859
# 0.812689350392492 0.807983796116135 0.817394904668849
# 3156.4599683929005
# 3119.8078653051302
# 14 292 1066
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4
# 0.7491425885873516 0.7421580096649628 0.7561271675097404
# 0.7679834433354912 0.7587578529461967 0.7772090337247857
# 0.7701703120315734 0.7630285115068751 0.7773121125562716
# 4063.830006483507
# 3995.5125617959316

# %%
import numpy as np
from scipy.stats import rankdata
import sys
import pandas as pd 

vps = set()
with open('data/train_1000.txt', 'r') as f:
        next(f)
        for line in f:
            items = line.strip().split()
            vp = items[1]
            vps.add(vp)
print(len(vps)) 

option2method = {"joint":"joint", "seq":"seq", "go":"seq+human embedding", "pheno":"seq+viral embedding", 
                 "rcnn":"RCNN", "rf": "Doc2Vec+RF"}
options = ["joint", "seq", "go", "pheno", "rcnn", "rf"]
for option in options:  
    with open(f"preds/ranks_{option}.txt", "w") as w:
        path = f'preds/preds_{option}_'
        count = 0
        for i in range(5):
            print('Going through prediction file ', count)
            count += 1

            vp_true, vp_false = {}, {}
            for vp in vps:
                vp_true[vp] = []
                vp_false[vp] = []

            with open(f"{path}{i}.txt", 'r') as f:
                for line in f:
                    items = line.strip().split("\t")
                    vp = items[0]
                    label = items[5]
                    score = float(items[4])
                    if label == "True":
                        vp_true[vp].append(score)
                    elif label == "False":
                        vp_false[vp].append(score)

            y_ranks = []
            for vp in vps:
                y_pred = np.concatenate((vp_true[vp], vp_false[vp]))
                y_ranks = np.concatenate((y_ranks, rankdata(-y_pred)[:len(vp_true[vp])]))

            for rank in y_ranks:
                w.write("%d\t%s\n" % (rank, option2method[option]))
# Out:
# 1066
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4
# Going through prediction file  0
# Going through prediction file  1
# Going through prediction file  2
# Going through prediction file  3
# Going through prediction file  4

# %%
vp_set = set()
preds_list = {}
hp_list = {}
vp2patho = {}
folds = 5
for i in range(folds):
    preds_file = f'preds_joint_t2697049_v694009_species_{i}.txt'
    with open(preds_file, 'r') as f:
        for line in f:
            items = line.strip().split("\t")
            if items[5] == 'True':
                continue
            vp = items[0]
            if "orf10" not in vp:
                continue
            vp_set.add(vp)
            vp2patho[vp] = items[2]
            if vp not in preds_list:
                preds_list[vp] = {}
                for ind in range(folds):
                    preds_list[vp][ind] = []
            if vp not in hp_list:
                hp_list[vp] = {}
                for ind in range(folds):
                    hp_list[vp][ind] = []
                
            preds_list[vp][i].append(float(items[4]))                
            hp_list[vp][i].append(items[1])
               
print(len(vp_set), len(preds_list), len(hp_list))
# Out:
# 1 1 1

# %%
hp_counts = {} 
with open("hps_in_positives.txt", 'r') as f:
    for line in f:
        items = line.strip().split()
        hp_counts[items[0]] = items[1]

# %%
import numpy as np
species_top = {}
num_top = 1000

query = "P50897"
for vp in vp_set:
    patho = vp2patho[vp]
    if patho not in species_top:
            species_top[patho] = set()
    preds = preds_list[vp]
    hps = np.array(hp_list[vp][0])
    top_hps = hps[np.argsort(preds_list[vp][0])][-num_top:]
    species_top[patho] = set(top_hps)
    for i in range(folds-1): 
        hps = np.array(hp_list[vp][i+1])
        top_hps = hps[np.argsort(preds_list[vp][i+1])][-num_top:]
        species_top[patho] = species_top[patho] & set(top_hps)

# %%
for hp in species_top["<http://purl.obolibrary.org/obo/NCBITaxon_2697049>"]:
    if hp not in hp_counts:
        print(hp)
    #print(hp, hp_counts[hp])
# Out:
# Q8NEV1

# %%
vp_set = set()
preds_list = {}
hp_list = {}
vp2patho = {}
folds = 5
for i in range(folds):
    preds_file = f'preds_joint_t2043570_v64320_species_{i}.txt'
    with open(preds_file, 'r') as f:
        for line in f:
            items = line.strip().split("\t")
            vp = items[0]
            if "A0A024B7W1-PRO_0000443029" not in vp:
                continue
            vp_set.add(vp)
            vp2patho[vp] = items[2]
            if vp not in preds_list:
                preds_list[vp] = {}
                for ind in range(folds):
                    preds_list[vp][ind] = []
            if vp not in hp_list:
                hp_list[vp] = {}
                for ind in range(folds):
                    hp_list[vp][ind] = []
                
            preds_list[vp][i].append(float(items[4]))                
            hp_list[vp][i].append(items[1])
               
print(len(vp_set), len(preds_list), len(hp_list))
# Out:
# 1 1 1

# %%
import numpy as np
from scipy.stats import rankdata

num_top = 1000

# queries = {"P50897":[], "Q13617":[], "Q3KQU3":[], "Q9BU02":[], "Q9C0D3":[], "Q9Y5J9":[], "P62877":[], 
#          "Q15369":[], "Q15370":[]}

hp_ranks = {}
for vp in vp_set:
    patho = vp2patho[vp]
    preds = preds_list[vp]
    for i in range(folds):
        hps = np.array(hp_list[vp][i])
        ranks = 16627 + 1 - rankdata(preds_list[vp][i])
        for j in range(len(hps)):
            hp = hps[j]
            rank = ranks[j]
            if i == 0:
                hp_ranks[hp] = 0 
            hp_ranks[hp] += rank
print(len(hp_ranks))
# Out:
# 16627

# %%
import operator
hp_ranks_sorted = sorted(hp_ranks.items(), key=operator.itemgetter(1))
hp_ranks_sorted = np.array(hp_ranks_sorted)
list(hp_ranks_sorted)
# Out:
# [array(['P0CG48', '277.0'], dtype='<U10'),
#  array(['P05412', '331.5'], dtype='<U10'),
#  array(['Q9BQE3', '516.0'], dtype='<U10'),
#  array(['P06748', '544.0'], dtype='<U10'),
#  array(['P63279', '571.0'], dtype='<U10'),
#  array(['P07437', '587.0'], dtype='<U10'),
#  array(['P11142', '607.5'], dtype='<U10'),
#  array(['Q12906', '638.0'], dtype='<U10'),
#  array(['P29590', '669.0'], dtype='<U10'),
#  array(['P22626', '673.0'], dtype='<U10'),
#  array(['Q96CV9', '694.0'], dtype='<U10'),
#  array(['P12814', '697.0'], dtype='<U10'),
#  array(['P0DMV8', '704.0'], dtype='<U10'),
#  array(['P68363', '706.0'], dtype='<U10'),
#  array(['Q02539', '711.0'], dtype='<U10'),
#  array(['P52294', '713.0'], dtype='<U10'),
#  array(['P25788', '724.0'], dtype='<U10'),
#  array(['P07900', '741.0'], dtype='<U10'),
#  array(['O60506', '746.0'], dtype='<U10'),
#  array(['P19338', '758.0'], dtype='<U10'),
#  array(['P27694', '769.0'], dtype='<U10'),
#  array(['Q13616', '790.0'], dtype='<U10'),
#  array(['P14618', '809.0'], dtype='<U10'),
#  array(['Q14457', '835.0'], dtype='<U10'),
#  array(['P40227', '885.0'], dtype='<U10'),
#  array(['P08238', '889.0'], dtype='<U10'),
#  array(['Q14974', '889.5'], dtype='<U10'),
#  array(['Q13573', '904.0'], dtype='<U10'),
#  array(['P61978', '907.0'], dtype='<U10'),
#  array(['P08047', '908.0'], dtype='<U10'),
#  array(['O43390', '934.0'], dtype='<U10'),
#  array(['P09651', '996.0'], dtype='<U10'),
#  array(['Q12800', '998.0'], dtype='<U10'),
#  array(['P01106', '999.0'], dtype='<U10'),
#  array(['P61956', '1007.0'], dtype='<U10'),
#  array(['P68371', '1012.0'], dtype='<U10'),
#  array(['P62877', '1019.0'], dtype='<U10'),
#  array(['P30153', '1035.0'], dtype='<U10'),
#  array(['P34932', '1040.0'], dtype='<U10'),
#  array(['Q00987', '1055.0'], dtype='<U10'),
#  array(['P27348', '1073.0'], dtype='<U10'),
#  array(['Q00839', '1077.0'], dtype='<U10'),
#  array(['P14625', '1081.0'], dtype='<U10'),
#  array(['Q01844', '1091.0'], dtype='<U10'),
#  array(['P52292', '1098.0'], dtype='<U10'),
#  array(['Q92973', '1103.0'], dtype='<U10'),
#  array(['Q92905', '1105.0'], dtype='<U10'),
#  array(['P50570', '1106.0'], dtype='<U10'),
#  array(['O15226', '1116.0'], dtype='<U10'),
#  array(['Q13162', '1119.0'], dtype='<U10'),
#  array(['P17980', '1119.0'], dtype='<U10'),
#  array(['P34931', '1124.0'], dtype='<U10'),
#  array(['Q92831', '1127.0'], dtype='<U10'),
#  array(['P11021', '1131.0'], dtype='<U10'),
#  array(['Q71U36', '1138.0'], dtype='<U10'),
#  array(['Q9UMX0', '1146.0'], dtype='<U10'),
#  array(['Q01860', '1156.0'], dtype='<U10'),
#  array(['P62987', '1156.0'], dtype='<U10'),
#  array(['P0CG47', '1158.0'], dtype='<U10'),
#  array(['Q13547', '1171.0'], dtype='<U10'),
#  array(['O00571', '1173.5'], dtype='<U10'),
#  array(['P19838', '1175.0'], dtype='<U10'),
#  array(['P26599', '1178.0'], dtype='<U10'),
#  array(['P42224', '1185.0'], dtype='<U10'),
#  array(['P19525', '1208.0'], dtype='<U10'),
#  array(['P17844', '1228.0'], dtype='<U10'),
#  array(['P23246', '1229.0'], dtype='<U10'),
#  array(['P67775', '1230.0'], dtype='<U10'),
#  array(['P24941', '1239.0'], dtype='<U10'),
#  array(['P68400', '1264.0'], dtype='<U10'),
#  array(['P62269', '1280.0'], dtype='<U10'),
#  array(['P49411', '1301.0'], dtype='<U10'),
#  array(['P62195', '1311.0'], dtype='<U10'),
#  array(['Q9Y6K9', '1314.0'], dtype='<U10'),
#  array(['P60842', '1319.0'], dtype='<U10'),
#  array(['P07355', '1320.0'], dtype='<U10'),
#  array(['Q9Y297', '1329.0'], dtype='<U10'),
#  array(['O00629', '1344.0'], dtype='<U10'),
#  array(['P13639', '1350.0'], dtype='<U10'),
#  array(['P33993', '1362.0'], dtype='<U10'),
#  array(['P27824', '1377.0'], dtype='<U10'),
#  array(['P10809', '1378.0'], dtype='<U10'),
#  array(['Q7KZF4', '1378.0'], dtype='<U10'),
#  array(['Q13619', '1396.0'], dtype='<U10'),
#  array(['P61221', '1406.0'], dtype='<U10'),
#  array(['P62937', '1419.0'], dtype='<U10'),
#  array(['P11940', '1428.0'], dtype='<U10'),
#  array(['P38646', '1434.0'], dtype='<U10'),
#  array(['P20042', '1438.0'], dtype='<U10'),
#  array(['P20226', '1445.0'], dtype='<U10'),
#  array(['Q92841', '1445.0'], dtype='<U10'),
#  array(['P25490', '1447.0'], dtype='<U10'),
#  array(['P06733', '1452.0'], dtype='<U10'),
#  array(['O15131', '1456.0'], dtype='<U10'),
#  array(['Q02878', '1458.0'], dtype='<U10'),
#  array(['P28482', '1458.5'], dtype='<U10'),
#  array(['P43243', '1471.0'], dtype='<U10'),
#  array(['P35637', '1473.0'], dtype='<U10'),
#  array(['P48643', '1493.0'], dtype='<U10'),
#  array(['Q96EY1', '1499.0'], dtype='<U10'),
#  array(['Q9BUJ2', '1521.0'], dtype='<U10'),
#  array(['P14866', '1523.0'], dtype='<U10'),
#  array(['P07910', '1525.5'], dtype='<U10'),
#  array(['Q07021', '1544.0'], dtype='<U10'),
#  array(['P49368', '1561.0'], dtype='<U10'),
#  array(['Q04206', '1566.0'], dtype='<U10'),
#  array(['O60684', '1590.5'], dtype='<U10'),
#  array(['Q8IUQ4', '1591.0'], dtype='<U10'),
#  array(['Q9Y230', '1591.0'], dtype='<U10'),
#  array(['Q8N9N5', '1600.0'], dtype='<U10'),
#  array(['Q13155', '1612.0'], dtype='<U10'),
#  array(['Q9Y4L1', '1628.0'], dtype='<U10'),
#  array(['P50990', '1631.0'], dtype='<U10'),
#  array(['P53618', '1640.0'], dtype='<U10'),
#  array(['P02511', '1643.0'], dtype='<U10'),
#  array(['P12956', '1644.0'], dtype='<U10'),
#  array(['Q92499', '1647.0'], dtype='<U10'),
#  array(['Q15370', '1654.0'], dtype='<U10'),
#  array(['P63104', '1655.0'], dtype='<U10'),
#  array(['P35232', '1656.0'], dtype='<U10'),
#  array(['P31943', '1657.0'], dtype='<U10'),
#  array(['O00505', '1659.0'], dtype='<U10'),
#  array(['P02768', '1661.0'], dtype='<U10'),
#  array(['P67809', '1663.0'], dtype='<U10'),
#  array(['Q6P1J9', '1664.0'], dtype='<U10'),
#  array(['Q02818', '1666.0'], dtype='<U10'),
#  array(['Q01105', '1673.0'], dtype='<U10'),
#  array(['P25705', '1678.0'], dtype='<U10'),
#  array(['P35268', '1681.0'], dtype='<U10'),
#  array(['P52272', '1701.0'], dtype='<U10'),
#  array(['Q8N163', '1702.0'], dtype='<U10'),
#  array(['P05141', '1709.0'], dtype='<U10'),
#  array(['Q9NR30', '1712.0'], dtype='<U10'),
#  array(['Q99873', '1714.0'], dtype='<U10'),
#  array(['P22087', '1717.0'], dtype='<U10'),
#  array(['Q16891', '1718.0'], dtype='<U10'),
#  array(['Q9NVI7', '1719.0'], dtype='<U10'),
#  array(['O95816', '1721.0'], dtype='<U10'),
#  array(['P17252', '1729.0'], dtype='<U10'),
#  array(['Q9UER7', '1730.5'], dtype='<U10'),
#  array(['P55072', '1732.0'], dtype='<U10'),
#  array(['Q9UKV8', '1741.0'], dtype='<U10'),
#  array(['Q13885', '1746.0'], dtype='<U10'),
#  array(['O75928', '1753.0'], dtype='<U10'),
#  array(['P51991', '1758.0'], dtype='<U10'),
#  array(['P11387', '1762.0'], dtype='<U10'),
#  array(['Q16543', '1765.0'], dtype='<U10'),
#  array(['Q14697', '1767.0'], dtype='<U10'),
#  array(['P62750', '1798.0'], dtype='<U10'),
#  array(['P17987', '1799.0'], dtype='<U10'),
#  array(['P53999', '1801.0'], dtype='<U10'),
#  array(['P78371', '1803.0'], dtype='<U10'),
#  array(['Q99459', '1808.0'], dtype='<U10'),
#  array(['Q99623', '1813.0'], dtype='<U10'),
#  array(['P31946', '1814.0'], dtype='<U10'),
#  array(['P68104', '1817.0'], dtype='<U10'),
#  array(['P62191', '1818.0'], dtype='<U10'),
#  array(['P46777', '1821.0'], dtype='<U10'),
#  array(['P06400', '1827.5'], dtype='<U10'),
#  array(['Q9H4L4', '1829.0'], dtype='<U10'),
#  array(['O95817', '1831.0'], dtype='<U10'),
#  array(['P60709', '1842.0'], dtype='<U10'),
#  array(['O14979', '1842.0'], dtype='<U10'),
#  array(['P62979', '1844.0'], dtype='<U10'),
#  array(['P68366', '1846.5'], dtype='<U10'),
#  array(['P62829', '1848.0'], dtype='<U10'),
#  array(['O00425', '1858.0'], dtype='<U10'),
#  array(['P04637', '1859.0'], dtype='<U10'),
#  array(['P36578', '1861.0'], dtype='<U10'),
#  array(['Q12905', '1861.0'], dtype='<U10'),
#  array(['P56545', '1867.0'], dtype='<U10'),
#  array(['O00567', '1877.0'], dtype='<U10'),
#  array(['P04843', '1905.0'], dtype='<U10'),
#  array(['Q15843', '1906.0'], dtype='<U10'),
#  array(['Q07812', '1914.0'], dtype='<U10'),
#  array(['Q99729', '1920.5'], dtype='<U10'),
#  array(['Q00325', '1931.0'], dtype='<U10'),
#  array(['Q15717', '1940.0'], dtype='<U10'),
#  array(['Q99816', '1942.5'], dtype='<U10'),
#  array(['P31689', '1947.0'], dtype='<U10'),
#  array(['Q14694', '1952.0'], dtype='<U10'),
#  array(['O43707', '1954.0'], dtype='<U10'),
#  array(['P13010', '1963.0'], dtype='<U10'),
#  array(['P06493', '1966.0'], dtype='<U10'),
#  array(['P63244', '1966.5'], dtype='<U10'),
#  array(['Q8IYB3', '1971.0'], dtype='<U10'),
#  array(['Q15233', '1978.5'], dtype='<U10'),
#  array(['P61289', '1982.0'], dtype='<U10'),
#  array(['P50750', '1988.0'], dtype='<U10'),
#  array(['P04350', '1993.5'], dtype='<U10'),
#  array(['Q9Y6X2', '1995.0'], dtype='<U10'),
#  array(['P08865', '2005.0'], dtype='<U10'),
#  array(['P04792', '2006.0'], dtype='<U10'),
#  array(['Q13363', '2026.0'], dtype='<U10'),
#  array(['P55209', '2035.0'], dtype='<U10'),
#  array(['O94826', '2038.0'], dtype='<U10'),
#  array(['P08621', '2040.0'], dtype='<U10'),
#  array(['P18124', '2045.0'], dtype='<U10'),
#  array(['O76021', '2046.0'], dtype='<U10'),
#  array(['P12004', '2050.0'], dtype='<U10'),
#  array(['P62993', '2060.0'], dtype='<U10'),
#  array(['P14314', '2065.5'], dtype='<U10'),
#  array(['Q04837', '2068.0'], dtype='<U10'),
#  array(['Q14103', '2081.0'], dtype='<U10'),
#  array(['Q9UNE7', '2086.0'], dtype='<U10'),
#  array(['P27361', '2105.0'], dtype='<U10'),
#  array(['P42677', '2105.0'], dtype='<U10'),
#  array(['Q9Y262', '2106.0'], dtype='<U10'),
#  array(['Q96AG4', '2116.0'], dtype='<U10'),
#  array(['Q15691', '2133.0'], dtype='<U10'),
#  array(['Q07666', '2141.5'], dtype='<U10'),
#  array(['P26368', '2142.0'], dtype='<U10'),
#  array(['P62826', '2144.0'], dtype='<U10'),
#  array(['P27797', '2149.0'], dtype='<U10'),
#  array(['P10515', '2168.5'], dtype='<U10'),
#  array(['P42771', '2190.0'], dtype='<U10'),
#  array(['P46778', '2191.0'], dtype='<U10'),
#  array(['Q5QJE6', '2191.5'], dtype='<U10'),
#  array(['P62244', '2195.0'], dtype='<U10'),
#  array(['P63151', '2198.0'], dtype='<U10'),
#  array(['Q15046', '2223.5'], dtype='<U10'),
#  array(['P08670', '2226.0'], dtype='<U10'),
#  array(['Q07955', '2234.0'], dtype='<U10'),
#  array(['P61981', '2241.0'], dtype='<U10'),
#  array(['P55884', '2241.0'], dtype='<U10'),
#  array(['P67870', '2244.0'], dtype='<U10'),
#  array(['Q96S59', '2249.0'], dtype='<U10'),
#  array(['P20700', '2250.0'], dtype='<U10'),
#  array(['P62277', '2252.0'], dtype='<U10'),
#  array(['Q14790', '2267.0'], dtype='<U10'),
#  array(['Q86U42', '2268.0'], dtype='<U10'),
#  array(['P21796', '2272.0'], dtype='<U10'),
#  array(['P04049', '2273.0'], dtype='<U10'),
#  array(['Q15637', '2284.0'], dtype='<U10'),
#  array(['P62913', '2286.0'], dtype='<U10'),
#  array(['P36873', '2298.0'], dtype='<U10'),
#  array(['P04406', '2299.0'], dtype='<U10'),
#  array(['P23396', '2301.0'], dtype='<U10'),
#  array(['Q9NTK5', '2304.0'], dtype='<U10'),
#  array(['P47897', '2306.0'], dtype='<U10'),
#  array(['Q9BYM8', '2318.0'], dtype='<U10'),
#  array(['Q9GZR7', '2325.0'], dtype='<U10'),
#  array(['P05783', '2336.0'], dtype='<U10'),
#  array(['O00303', '2349.0'], dtype='<U10'),
#  array(['P50991', '2362.0'], dtype='<U10'),
#  array(['P78344', '2363.5'], dtype='<U10'),
#  array(['Q9UQ80', '2374.0'], dtype='<U10'),
#  array(['P26641', '2376.0'], dtype='<U10'),
#  array(['Q9Y224', '2378.5'], dtype='<U10'),
#  array(['P17096', '2381.5'], dtype='<U10'),
#  array(['Q13151', '2383.0'], dtype='<U10'),
#  array(['Q9Y3I0', '2388.0'], dtype='<U10'),
#  array(['Q15427', '2391.0'], dtype='<U10'),
#  array(['O76094', '2404.0'], dtype='<U10'),
#  array(['P06576', '2405.0'], dtype='<U10'),
#  array(['Q14978', '2408.0'], dtype='<U10'),
#  array(['P55036', '2409.0'], dtype='<U10'),
#  array(['P63208', '2409.0'], dtype='<U10'),
#  array(['O14744', '2414.0'], dtype='<U10'),
#  array(['O15371', '2427.0'], dtype='<U10'),
#  array(['P62805', '2460.5'], dtype='<U10'),
#  array(['P30050', '2461.0'], dtype='<U10'),
#  array(['O95292', '2462.0'], dtype='<U10'),
#  array(['Q93062', '2469.0'], dtype='<U10'),
#  array(['Q92769', '2478.0'], dtype='<U10'),
#  array(['P05198', '2481.0'], dtype='<U10'),
#  array(['P11441', '2495.0'], dtype='<U10'),
#  array(['Q15020', '2497.0'], dtype='<U10'),
#  array(['P29692', '2498.5'], dtype='<U10'),
#  array(['P15927', '2508.0'], dtype='<U10'),
#  array(['P62249', '2510.0'], dtype='<U10'),
#  array(['Q2NL82', '2517.0'], dtype='<U10'),
#  array(['Q13111', '2517.0'], dtype='<U10'),
#  array(['P55060', '2523.0'], dtype='<U10'),
#  array(['Q13200', '2524.0'], dtype='<U10'),
#  array(['P39019', '2531.0'], dtype='<U10'),
#  array(['O43143', '2539.0'], dtype='<U10'),
#  array(['P17066', '2546.0'], dtype='<U10'),
#  array(['Q99460', '2551.0'], dtype='<U10'),
#  array(['P30101', '2552.0'], dtype='<U10'),
#  array(['P20248', '2555.0'], dtype='<U10'),
#  array(['Q92945', '2562.0'], dtype='<U10'),
#  array(['Q99848', '2570.0'], dtype='<U10'),
#  array(['Q96I24', '2574.5'], dtype='<U10'),
#  array(['Q9UHD9', '2576.5'], dtype='<U10'),
#  array(['P08195', '2578.0'], dtype='<U10'),
#  array(['P98179', '2580.0'], dtype='<U10'),
#  array(['P61247', '2585.0'], dtype='<U10'),
#  array(['Q92993', '2588.0'], dtype='<U10'),
#  array(['P19784', '2599.0'], dtype='<U10'),
#  array(['P54652', '2605.0'], dtype='<U10'),
#  array(['P84103', '2611.0'], dtype='<U10'),
#  array(['Q9NY93', '2617.0'], dtype='<U10'),
#  array(['P49458', '2619.0'], dtype='<U10'),
#  array(['Q15084', '2629.0'], dtype='<U10'),
#  array(['Q9NYJ8', '2634.0'], dtype='<U10'),
#  array(['Q96J02', '2641.0'], dtype='<U10'),
#  array(['Q12933', '2642.0'], dtype='<U10'),
#  array(['P35998', '2646.0'], dtype='<U10'),
#  array(['P42166', '2647.5'], dtype='<U10'),
#  array(['Q8TAE8', '2656.0'], dtype='<U10'),
#  array(['Q9C0B0', '2659.0'], dtype='<U10'),
#  array(['Q15172', '2673.0'], dtype='<U10'),
#  array(['P60866', '2678.0'], dtype='<U10'),
#  array(['Q13263', '2682.0'], dtype='<U10'),
#  array(['P62258', '2685.0'], dtype='<U10'),
#  array(['P22695', '2688.0'], dtype='<U10'),
#  array(['Q14498', '2688.5'], dtype='<U10'),
#  array(['O00459', '2690.0'], dtype='<U10'),
#  array(['O15379', '2701.0'], dtype='<U10'),
#  array(['P52597', '2702.0'], dtype='<U10'),
#  array(['O95793', '2702.5'], dtype='<U10'),
#  array(['Q9UL18', '2708.0'], dtype='<U10'),
#  array(['Q13148', '2727.0'], dtype='<U10'),
#  array(['Q8N448', '2737.0'], dtype='<U10'),
#  array(['Q96HR8', '2739.5'], dtype='<U10'),
#  array(['P62136', '2743.5'], dtype='<U10'),
#  array(['O14965', '2747.0'], dtype='<U10'),
#  array(['P16989', '2751.0'], dtype='<U10'),
#  array(['P15880', '2760.0'], dtype='<U10'),
#  array(['P37108', '2760.0'], dtype='<U10'),
#  array(['Q8NE71', '2765.0'], dtype='<U10'),
#  array(['Q9BUF5', '2766.0'], dtype='<U10'),
#  array(['Q05682', '2768.0'], dtype='<U10'),
#  array(['P62263', '2771.0'], dtype='<U10'),
#  array(['P63220', '2778.0'], dtype='<U10'),
#  array(['Q96PK6', '2780.0'], dtype='<U10'),
#  array(['P42766', '2780.0'], dtype='<U10'),
#  array(['Q16630', '2784.0'], dtype='<U10'),
#  array(['O43852', '2794.0'], dtype='<U10'),
#  array(['O14818', '2804.0'], dtype='<U10'),
#  array(['P62736', '2816.0'], dtype='<U10'),
#  array(['P50402', '2818.0'], dtype='<U10'),
#  array(['P05388', '2818.0'], dtype='<U10'),
#  array(['O00429', '2821.0'], dtype='<U10'),
#  array(['P35249', '2838.0'], dtype='<U10'),
#  array(['P35221', '2839.0'], dtype='<U10'),
#  array(['Q9Y5V3', '2840.0'], dtype='<U10'),
#  array(['P62841', '2843.0'], dtype='<U10'),
#  array(['P63165', '2848.0'], dtype='<U10'),
#  array(['O96008', '2852.0'], dtype='<U10'),
#  array(['Q14684', '2857.0'], dtype='<U10'),
#  array(['Q9UKB1', '2859.0'], dtype='<U10'),
#  array(['O43242', '2862.0'], dtype='<U10'),
#  array(['P25685', '2867.0'], dtype='<U10'),
#  array(['Q86VM9', '2876.0'], dtype='<U10'),
#  array(['P31749', '2880.0'], dtype='<U10'),
#  array(['Q13283', '2881.0'], dtype='<U10'),
#  array(['Q14258', '2885.0'], dtype='<U10'),
#  array(['P26196', '2890.0'], dtype='<U10'),
#  array(['P43246', '2891.0'], dtype='<U10'),
#  array(['Q9Y6Y0', '2905.0'], dtype='<U10'),
#  array(['P21912', '2906.0'], dtype='<U10'),
#  array(['Q9Y265', '2917.0'], dtype='<U10'),
#  array(['P62857', '2919.5'], dtype='<U10'),
#  array(['Q9BVP2', '2919.5'], dtype='<U10'),
#  array(['P51149', '2925.0'], dtype='<U10'),
#  array(['P13667', '2926.0'], dtype='<U10'),
#  array(['P49336', '2926.0'], dtype='<U10'),
#  array(['P14859', '2947.0'], dtype='<U10'),
#  array(['P12236', '2956.0'], dtype='<U10'),
#  array(['P17480', '2958.0'], dtype='<U10'),
#  array(['P62266', '2960.5'], dtype='<U10'),
#  array(['Q1KMD3', '2962.0'], dtype='<U10'),
#  array(['Q9NY65', '2962.0'], dtype='<U10'),
#  array(['Q05086', '2970.0'], dtype='<U10'),
#  array(['O00308', '2971.5'], dtype='<U10'),
#  array(['Q9UHX1', '2972.0'], dtype='<U10'),
#  array(['Q86UK7', '2983.0'], dtype='<U10'),
#  array(['Q5T9A4', '2984.0'], dtype='<U10'),
#  array(['P22736', '2992.0'], dtype='<U10'),
#  array(['P62333', '2993.0'], dtype='<U10'),
#  array(['P56192', '3001.0'], dtype='<U10'),
#  array(['P27635', '3009.0'], dtype='<U10'),
#  array(['Q9UHB9', '3009.0'], dtype='<U10'),
#  array(['O95229', '3012.0'], dtype='<U10'),
#  array(['Q14240', '3013.0'], dtype='<U10'),
#  array(['Q16611', '3015.0'], dtype='<U10'),
#  array(['Q15366', '3016.0'], dtype='<U10'),
#  array(['Q15369', '3022.0'], dtype='<U10'),
#  array(['O75475', '3031.0'], dtype='<U10'),
#  array(['P62899', '3045.5'], dtype='<U10'),
#  array(['Q12931', '3054.0'], dtype='<U10'),
#  array(['P55769', '3059.0'], dtype='<U10'),
#  array(['P60228', '3060.0'], dtype='<U10'),
#  array(['Q13617', '3061.5'], dtype='<U10'),
#  array(['O14920', '3072.0'], dtype='<U10'),
#  array(['P07305', '3084.0'], dtype='<U10'),
#  array(['Q9P0K7', '3094.0'], dtype='<U10'),
#  array(['P07237', '3104.0'], dtype='<U10'),
#  array(['P63010', '3104.0'], dtype='<U10'),
#  array(['O60832', '3105.0'], dtype='<U10'),
#  array(['P10412', '3111.5'], dtype='<U10'),
#  array(['P62701', '3125.0'], dtype='<U10'),
#  array(['P38159', '3131.0'], dtype='<U10'),
#  array(['P55084', '3136.0'], dtype='<U10'),
#  array(['Q06830', '3144.0'], dtype='<U10'),
#  array(['O60563', '3148.0'], dtype='<U10'),
#  array(['Q9Y5L4', '3157.0'], dtype='<U10'),
#  array(['Q99832', '3162.0'], dtype='<U10'),
#  array(['Q71UM5', '3176.0'], dtype='<U10'),
#  array(['P23258', '3176.0'], dtype='<U10'),
#  array(['P61201', '3184.0'], dtype='<U10'),
#  array(['P07947', '3184.0'], dtype='<U10'),
#  array(['O15381', '3187.0'], dtype='<U10'),
#  array(['P62714', '3190.0'], dtype='<U10'),
#  array(['Q92542', '3191.0'], dtype='<U10'),
#  array(['Q969H0', '3201.0'], dtype='<U10'),
#  array(['P05455', '3221.0'], dtype='<U10'),
#  array(['Q8NC51', '3222.0'], dtype='<U10'),
#  array(['Q96SB4', '3224.0'], dtype='<U10'),
#  array(['P82650', '3225.0'], dtype='<U10'),
#  array(['Q7Z3B4', '3227.0'], dtype='<U10'),
#  array(['P62753', '3233.0'], dtype='<U10'),
#  array(['P18621', '3237.0'], dtype='<U10'),
#  array(['O75531', '3239.0'], dtype='<U10'),
#  array(['P56537', '3245.0'], dtype='<U10'),
#  array(['Q7L2J0', '3248.0'], dtype='<U10'),
#  array(['Q13435', '3253.0'], dtype='<U10'),
#  array(['P62995', '3267.5'], dtype='<U10'),
#  array(['Q9BY44', '3275.0'], dtype='<U10'),
#  array(['P45880', '3278.0'], dtype='<U10'),
#  array(['P62847', '3282.0'], dtype='<U10'),
#  array(['Q15633', '3299.0'], dtype='<U10'),
#  array(['Q12904', '3301.0'], dtype='<U10'),
#  array(['P62241', '3306.0'], dtype='<U10'),
#  array(['Q9UI26', '3312.0'], dtype='<U10'),
#  array(['Q99613', '3313.0'], dtype='<U10'),
#  array(['Q13347', '3323.0'], dtype='<U10'),
#  array(['P84098', '3327.0'], dtype='<U10'),
#  array(['Q9UHI6', '3339.0'], dtype='<U10'),
#  array(['Q13561', '3341.0'], dtype='<U10'),
#  array(['P16104', '3345.0'], dtype='<U10'),
#  array(['P61513', '3347.0'], dtype='<U10'),
#  array(['Q8TDD1', '3365.0'], dtype='<U10'),
#  array(['Q8NEV1', '3366.0'], dtype='<U10'),
#  array(['P14868', '3369.0'], dtype='<U10'),
#  array(['Q9BUN8', '3379.0'], dtype='<U10'),
#  array(['Q16695', '3382.0'], dtype='<U10'),
#  array(['Q3ZCQ8', '3384.0'], dtype='<U10'),
#  array(['Q15365', '3385.0'], dtype='<U10'),
#  array(['Q9Y678', '3385.5'], dtype='<U10'),
#  array(['P62081', '3392.0'], dtype='<U10'),
#  array(['P54136', '3402.0'], dtype='<U10'),
#  array(['P16403', '3402.0'], dtype='<U10'),
#  array(['Q9BZE4', '3425.0'], dtype='<U10'),
#  array(['P62851', '3430.0'], dtype='<U10'),
#  array(['P82675', '3436.0'], dtype='<U10'),
#  array(['P23921', '3441.0'], dtype='<U10'),
#  array(['Q13501', '3442.0'], dtype='<U10'),
#  array(['Q8WVC0', '3449.0'], dtype='<U10'),
#  array(['Q9Y5L0', '3450.0'], dtype='<U10'),
#  array(['Q9UBT2', '3453.5'], dtype='<U10'),
#  array(['Q01130', '3463.0'], dtype='<U10'),
#  array(['Q92688', '3468.5'], dtype='<U10'),
#  array(['P82933', '3470.0'], dtype='<U10'),
#  array(['P40429', '3475.0'], dtype='<U10'),
#  array(['P33992', '3476.0'], dtype='<U10'),
#  array(['P39023', '3486.0'], dtype='<U10'),
#  array(['P35222', '3501.0'], dtype='<U10'),
#  array(['Q9Y6C9', '3502.0'], dtype='<U10'),
#  array(['P62917', '3503.0'], dtype='<U10'),
#  array(['O00231', '3512.0'], dtype='<U10'),
#  array(['Q15942', '3518.0'], dtype='<U10'),
#  array(['Q13526', '3529.0'], dtype='<U10'),
#  array(['Q14764', '3542.0'], dtype='<U10'),
#  array(['O95831', '3545.0'], dtype='<U10'),
#  array(['Q92997', '3548.5'], dtype='<U10'),
#  array(['Q9Y2W1', '3552.0'], dtype='<U10'),
#  array(['P27540', '3559.5'], dtype='<U10'),
#  array(['Q13137', '3577.0'], dtype='<U10'),
#  array(['P50454', '3584.0'], dtype='<U10'),
#  array(['O14733', '3587.0'], dtype='<U10'),
#  array(['P62424', '3590.0'], dtype='<U10'),
#  array(['P51398', '3598.5'], dtype='<U10'),
#  array(['O94906', '3613.0'], dtype='<U10'),
#  array(['Q6EMK4', '3615.0'], dtype='<U10'),
#  array(['P08559', '3620.0'], dtype='<U10'),
#  array(['Q63ZY3', '3626.5'], dtype='<U10'),
#  array(['P12235', '3635.0'], dtype='<U10'),
#  array(['O96017', '3640.0'], dtype='<U10'),
#  array(['P55795', '3640.0'], dtype='<U10'),
#  array(['P60468', '3641.0'], dtype='<U10'),
#  array(['P00558', '3648.0'], dtype='<U10'),
#  array(['P08240', '3666.0'], dtype='<U10'),
#  array(['Q16629', '3669.0'], dtype='<U10'),
#  array(['Q9P258', '3684.5'], dtype='<U10'),
#  array(['Q9Y5Q9', '3687.0'], dtype='<U10'),
#  array(['P40938', '3688.0'], dtype='<U10'),
#  array(['P43686', '3689.0'], dtype='<U10'),
#  array(['P16402', '3691.0'], dtype='<U10'),
#  array(['Q92804', '3708.5'], dtype='<U10'),
#  array(['Q66K89', '3710.0'], dtype='<U10'),
#  array(['O95758', '3711.0'], dtype='<U10'),
#  array(['Q6UN15', '3712.0'], dtype='<U10'),
#  array(['P46782', '3713.0'], dtype='<U10'),
#  array(['P10144', '3713.0'], dtype='<U10'),
#  array(['Q99933', '3719.5'], dtype='<U10'),
#  array(['P61353', '3720.0'], dtype='<U10'),
#  array(['O75569', '3721.0'], dtype='<U10'),
#  array(['P57740', '3729.0'], dtype='<U10'),
#  array(['P31040', '3738.0'], dtype='<U10'),
#  array(['P23588', '3739.0'], dtype='<U10'),
#  array(['P63261', '3740.0'], dtype='<U10'),
#  array(['O00499', '3745.0'], dtype='<U10'),
#  array(['P62280', '3746.0'], dtype='<U10'),
#  array(['P05386', '3751.0'], dtype='<U10'),
#  array(['O60763', '3754.0'], dtype='<U10'),
#  array(['P10599', '3761.0'], dtype='<U10'),
#  array(['Q14192', '3762.0'], dtype='<U10'),
#  array(['Q8TBB1', '3784.0'], dtype='<U10'),
#  array(['P12277', '3803.0'], dtype='<U10'),
#  array(['P35269', '3806.0'], dtype='<U10'),
#  array(['Q9Y6M1', '3813.0'], dtype='<U10'),
#  array(['Q14653', '3815.0'], dtype='<U10'),
#  array(['P46060', '3826.0'], dtype='<U10'),
#  array(['P39687', '3827.0'], dtype='<U10'),
#  array(['P83731', '3850.0'], dtype='<U10'),
#  array(['Q09028', '3852.5'], dtype='<U10'),
#  array(['Q5VTR2', '3854.0'], dtype='<U10'),
#  array(['P61313', '3856.0'], dtype='<U10'),
#  array(['P38919', '3865.0'], dtype='<U10'),
#  array(['Q99471', '3877.0'], dtype='<U10'),
#  array(['Q16665', '3878.0'], dtype='<U10'),
#  array(['P49756', '3879.0'], dtype='<U10'),
#  array(['P10276', '3886.0'], dtype='<U10'),
#  array(['P51665', '3889.0'], dtype='<U10'),
#  array(['O95573', '3893.5'], dtype='<U10'),
#  array(['P61619', '3898.5'], dtype='<U10'),
#  array(['P05787', '3902.0'], dtype='<U10'),
#  array(['Q96C10', '3904.0'], dtype='<U10'),
#  array(['Q13310', '3912.0'], dtype='<U10'),
#  array(['P30260', '3922.0'], dtype='<U10'),
#  array(['Q96EY7', '3926.0'], dtype='<U10'),
#  array(['Q92665', '3928.0'], dtype='<U10'),
#  array(['Q9P015', '3933.0'], dtype='<U10'),
#  array(['P14635', '3939.0'], dtype='<U10'),
#  array(['P50914', '3956.0'], dtype='<U10'),
#  array(['P60900', '3967.0'], dtype='<U10'),
#  array(['Q969G5', '3971.0'], dtype='<U10'),
#  array(['Q8IY81', '3977.0'], dtype='<U10'),
#  array(['P35544', '3984.0'], dtype='<U10'),
#  array(['Q03252', '3986.0'], dtype='<U10'),
#  array(['O43823', '3997.0'], dtype='<U10'),
#  array(['Q15311', '3997.0'], dtype='<U10'),
#  array(['P84243', '4002.0'], dtype='<U10'),
#  array(['P27986', '4007.0'], dtype='<U10'),
#  array(['Q14134', '4011.0'], dtype='<U10'),
#  array(['Q16778', '4015.0'], dtype='<U10'),
#  array(['Q9UG63', '4031.0'], dtype='<U10'),
#  array(['P62888', '4035.0'], dtype='<U10'),
#  array(['Q7Z2W4', '4035.5'], dtype='<U10'),
#  array(['Q9NXF1', '4041.0'], dtype='<U10'),
#  array(['P49959', '4042.0'], dtype='<U10'),
#  array(['Q9Y2R9', '4051.0'], dtype='<U10'),
#  array(['P06753', '4057.0'], dtype='<U10'),
#  array(['P40939', '4075.0'], dtype='<U10'),
#  array(['Q13724', '4078.0'], dtype='<U10'),
#  array(['Q14257', '4080.0'], dtype='<U10'),
#  array(['P84077', '4084.0'], dtype='<U10'),
#  array(['Q12824', '4110.0'], dtype='<U10'),
#  array(['Q16539', '4115.0'], dtype='<U10'),
#  array(['Q07020', '4115.0'], dtype='<U10'),
#  array(['P22234', '4123.0'], dtype='<U10'),
#  array(['P17612', '4124.0'], dtype='<U10'),
#  array(['Q13077', '4129.0'], dtype='<U10'),
#  array(['Q08945', '4136.0'], dtype='<U10'),
#  array(['P46783', '4136.0'], dtype='<U10'),
#  array(['Q9UPN7', '4137.0'], dtype='<U10'),
#  array(['Q9NS69', '4143.0'], dtype='<U10'),
#  array(['Q16777', '4156.0'], dtype='<U10'),
#  array(['O94763', '4162.0'], dtype='<U10'),
#  array(['P68133', '4165.0'], dtype='<U10'),
#  array(['P61254', '4167.0'], dtype='<U10'),
#  array(['O15372', '4169.0'], dtype='<U10'),
#  array(['Q8IXB1', '4170.0'], dtype='<U10'),
#  array(['Q13895', '4174.0'], dtype='<U10'),
#  array(['O60884', '4174.0'], dtype='<U10'),
#  array(['P33991', '4187.0'], dtype='<U10'),
#  array(['P26373', '4190.0'], dtype='<U10'),
#  array(['P07737', '4191.0'], dtype='<U10'),
#  array(['P25789', '4193.0'], dtype='<U10'),
#  array(['Q86X55', '4219.0'], dtype='<U10'),
#  array(['Q9Y277', '4221.0'], dtype='<U10'),
#  array(['Q12874', '4224.0'], dtype='<U10'),
#  array(['Q9Y295', '4230.5'], dtype='<U10'),
#  array(['Q9H6T3', '4233.5'], dtype='<U10'),
#  array(['Q06210', '4240.0'], dtype='<U10'),
#  array(['P62316', '4242.0'], dtype='<U10'),
#  array(['P02545', '4248.0'], dtype='<U10'),
#  array(['P49207', '4267.0'], dtype='<U10'),
#  array(['Q9ULX6', '4273.0'], dtype='<U10'),
#  array(['P46781', '4276.0'], dtype='<U10'),
#  array(['Q8N1F7', '4276.5'], dtype='<U10'),
#  array(['P24752', '4286.0'], dtype='<U10'),
#  array(['Q9H0D6', '4297.0'], dtype='<U10'),
#  array(['P05026', '4301.0'], dtype='<U10'),
#  array(['Q9Y676', '4304.0'], dtype='<U10'),
#  array(['Q8WWY3', '4306.0'], dtype='<U10'),
#  array(['Q99615', '4308.0'], dtype='<U10'),
#  array(['P30154', '4309.0'], dtype='<U10'),
#  array(['O43324', '4313.0'], dtype='<U10'),
#  array(['P52815', '4321.0'], dtype='<U10'),
#  array(['P12931', '4323.0'], dtype='<U10'),
#  array(['P02786', '4331.0'], dtype='<U10'),
#  array(['Q07817', '4338.0'], dtype='<U10'),
#  array(['P27105', '4343.0'], dtype='<U10'),
#  array(['Q9BQA1', '4353.0'], dtype='<U10'),
#  array(['P31942', '4382.0'], dtype='<U10'),
#  array(['P36542', '4384.0'], dtype='<U10'),
#  array(['P46776', '4388.0'], dtype='<U10'),
#  array(['P46779', '4394.0'], dtype='<U10'),
#  array(['Q13123', '4399.0'], dtype='<U10'),
#  array(['Q14145', '4407.0'], dtype='<U10'),
#  array(['Q9P2I0', '4409.0'], dtype='<U10'),
#  array(['P98082', '4419.0'], dtype='<U10'),
#  array(['Q9UHD8', '4426.0'], dtype='<U10'),
#  array(['Q9NVP1', '4441.0'], dtype='<U10'),
#  array(['P31948', '4446.0'], dtype='<U10'),
#  array(['Q9NZM5', '4446.0'], dtype='<U10'),
#  array(['O60869', '4453.0'], dtype='<U10'),
#  array(['P45983', '4455.0'], dtype='<U10'),
#  array(['P16220', '4463.5'], dtype='<U10'),
#  array(['P53007', '4468.0'], dtype='<U10'),
#  array(['P09382', '4471.0'], dtype='<U10'),
#  array(['Q9Y3U8', '4475.0'], dtype='<U10'),
#  array(['Q9BVK6', '4482.0'], dtype='<U10'),
#  array(['Q14254', '4485.0'], dtype='<U10'),
#  array(['P28066', '4487.0'], dtype='<U10'),
#  array(['O14641', '4489.5'], dtype='<U10'),
#  array(['P49736', '4491.0'], dtype='<U10'),
#  array(['P19367', '4494.0'], dtype='<U10'),
#  array(['Q07065', '4498.0'], dtype='<U10'),
#  array(['Q9UHV9', '4508.0'], dtype='<U10'),
#  array(['Q15459', '4509.0'], dtype='<U10'),
#  array(['P07384', '4510.0'], dtype='<U10'),
#  array(['Q9UNS2', '4511.0'], dtype='<U10'),
#  array(['Q8TAT6', '4518.0'], dtype='<U10'),
#  array(['P62314', '4528.0'], dtype='<U10'),
#  array(['P10275', '4532.0'], dtype='<U10'),
#  array(['Q9GZQ8', '4535.5'], dtype='<U10'),
#  array(['P46108', '4535.5'], dtype='<U10'),
#  array(['Q96CS3', '4542.0'], dtype='<U10'),
#  array(['A1L0T0', '4547.0'], dtype='<U10'),
#  array(['Q99733', '4551.0'], dtype='<U10'),
#  array(['P47914', '4551.0'], dtype='<U10'),
#  array(['P82930', '4553.0'], dtype='<U10'),
#  array(['P05387', '4558.0'], dtype='<U10'),
#  array(['O00716', '4559.0'], dtype='<U10'),
#  array(['P62487', '4560.0'], dtype='<U10'),
#  array(['P49257', '4561.0'], dtype='<U10'),
#  array(['Q9Y2X3', '4565.0'], dtype='<U10'),
#  array(['Q9P035', '4565.0'], dtype='<U10'),
#  array(['P37198', '4573.0'], dtype='<U10'),
#  array(['Q86V81', '4594.0'], dtype='<U10'),
#  array(['P25205', '4595.0'], dtype='<U10'),
#  array(['Q04917', '4610.5'], dtype='<U10'),
#  array(['Q92522', '4612.5'], dtype='<U10'),
#  array(['Q9BYN8', '4622.0'], dtype='<U10'),
#  array(['Q9UNX3', '4624.0'], dtype='<U10'),
#  array(['P28070', '4629.0'], dtype='<U10'),
#  array(['Q9BZE1', '4629.0'], dtype='<U10'),
#  array(['Q92541', '4631.0'], dtype='<U10'),
#  array(['P43307', '4635.5'], dtype='<U10'),
#  array(['Q6FI13', '4639.5'], dtype='<U10'),
#  array(['P30419', '4640.0'], dtype='<U10'),
#  array(['Q71DI3', '4641.0'], dtype='<U10'),
#  array(['Q9UIL1', '4647.0'], dtype='<U10'),
#  array(['Q9Y5X1', '4652.5'], dtype='<U10'),
#  array(['Q9UGP8', '4655.0'], dtype='<U10'),
#  array(['Q8N684', '4655.0'], dtype='<U10'),
#  array(['P25398', '4659.0'], dtype='<U10'),
#  array(['Q9H0S4', '4661.0'], dtype='<U10'),
#  array(['P41091', '4662.0'], dtype='<U10'),
#  array(['Q13185', '4665.0'], dtype='<U10'),
#  array(['Q71RC2', '4671.0'], dtype='<U10'),
#  array(['Q9BV38', '4673.0'], dtype='<U10'),
#  array(['O95433', '4680.0'], dtype='<U10'),
#  array(['Q7L2H7', '4695.5'], dtype='<U10'),
#  array(['P25786', '4701.0'], dtype='<U10'),
#  array(['P08758', '4703.0'], dtype='<U10'),
#  array(['Q9Y4E8', '4705.0'], dtype='<U10'),
#  array(['P32969', '4705.0'], dtype='<U10'),
#  array(['P25787', '4707.5'], dtype='<U10'),
#  array(['Q96TA2', '4714.0'], dtype='<U10'),
#  array(['O75925', '4715.5'], dtype='<U10'),
#  array(['P60660', '4717.0'], dtype='<U10'),
#  array(['P62906', '4722.5'], dtype='<U10'),
#  array(['P35250', '4725.0'], dtype='<U10'),
#  array(['Q9UMS4', '4727.0'], dtype='<U10'),
#  array(['P16401', '4731.0'], dtype='<U10'),
#  array(['P63241', '4734.0'], dtype='<U10'),
#  array(['P09661', '4746.0'], dtype='<U10'),
#  array(['Q9UHD2', '4746.0'], dtype='<U10'),
#  array(['Q13509', '4749.0'], dtype='<U10'),
#  array(['P09622', '4758.0'], dtype='<U10'),
#  array(['Q9NUL3', '4766.0'], dtype='<U10'),
#  array(['Q99757', '4773.5'], dtype='<U10'),
#  array(['Q9UKF6', '4776.0'], dtype='<U10'),
#  array(['Q96FW1', '4791.0'], dtype='<U10'),
#  array(['Q9UJV9', '4797.0'], dtype='<U10'),
#  array(['P09012', '4806.0'], dtype='<U10'),
#  array(['Q9UBE0', '4816.0'], dtype='<U10'),
#  array(['Q15796', '4819.0'], dtype='<U10'),
#  array(['P49023', '4820.0'], dtype='<U10'),
#  array(['Q00577', '4826.0'], dtype='<U10'),
#  array(['O95273', '4827.0'], dtype='<U10'),
#  array(['P38606', '4828.0'], dtype='<U10'),
#  array(['Q01167', '4834.0'], dtype='<U10'),
#  array(['O95782', '4837.0'], dtype='<U10'),
#  array(['Q9NR12', '4840.0'], dtype='<U10'),
#  array(['O75190', '4840.0'], dtype='<U10'),
#  array(['Q9UNQ2', '4848.5'], dtype='<U10'),
#  array(['P31930', '4853.0'], dtype='<U10'),
#  array(['P45973', '4860.0'], dtype='<U10'),
#  array(['P57772', '4861.0'], dtype='<U10'),
#  array(['O94829', '4875.0'], dtype='<U10'),
#  array(['P60903', '4878.0'], dtype='<U10'),
#  array(['P04844', '4885.0'], dtype='<U10'),
#  array(['Q4G0J3', '4893.0'], dtype='<U10'),
#  array(['P40937', '4894.0'], dtype='<U10'),
#  array(['Q8IXM3', '4908.0'], dtype='<U10'),
#  array(['Q9NVN8', '4911.0'], dtype='<U10'),
#  array(['P23526', '4913.5'], dtype='<U10'),
#  array(['P04004', '4914.0'], dtype='<U10'),
#  array(['P24534', '4930.0'], dtype='<U10'),
#  array(['O43592', '4932.0'], dtype='<U10'),
#  array(['Q16763', '4938.5'], dtype='<U10'),
#  array(['P13489', '4952.0'], dtype='<U10'),
#  array(['P19474', '4967.0'], dtype='<U10'),
#  array(['O75688', '4971.5'], dtype='<U10'),
#  array(['P03372', '4985.0'], dtype='<U10'),
#  array(['Q8TCJ2', '4985.0'], dtype='<U10'),
#  array(['Q96CW1', '5005.0'], dtype='<U10'),
#  array(['Q9Y5M8', '5011.0'], dtype='<U10'),
#  array(['O60341', '5011.0'], dtype='<U10'),
#  array(['O75821', '5014.0'], dtype='<U10'),
#  array(['P53350', '5016.0'], dtype='<U10'),
#  array(['Q8WUA4', '5022.0'], dtype='<U10'),
#  array(['Q15185', '5023.0'], dtype='<U10'),
#  array(['Q9Y2Z4', '5026.5'], dtype='<U10'),
#  array(['P61964', '5028.5'], dtype='<U10'),
#  array(['P08708', '5029.0'], dtype='<U10'),
#  array(['P35659', '5031.5'], dtype='<U10'),
#  array(['O95905', '5034.0'], dtype='<U10'),
#  array(['P12830', '5038.0'], dtype='<U10'),
#  array(['P61160', '5040.0'], dtype='<U10'),
#  array(['Q8TCG1', '5047.0'], dtype='<U10'),
#  array(['Q9Y383', '5052.0'], dtype='<U10'),
#  array(['Q9NZN8', '5060.0'], dtype='<U10'),
#  array(['Q8WU90', '5061.0'], dtype='<U10'),
#  array(['Q96B97', '5064.0'], dtype='<U10'),
#  array(['P61011', '5071.0'], dtype='<U10'),
#  array(['Q93034', '5071.0'], dtype='<U10'),
#  array(['Q13485', '5079.0'], dtype='<U10'),
#  array(['Q9NX58', '5081.0'], dtype='<U10'),
#  array(['P78347', '5083.0'], dtype='<U10'),
#  array(['O75152', '5100.0'], dtype='<U10'),
#  array(['Q9Y371', '5110.0'], dtype='<U10'),
#  array(['Q8TAF3', '5110.0'], dtype='<U10'),
#  array(['Q9NRX2', '5117.5'], dtype='<U10'),
#  array(['Q8IVS2', '5125.0'], dtype='<U10'),
#  array(['P28288', '5141.0'], dtype='<U10'),
#  array(['O75400', '5159.0'], dtype='<U10'),
#  array(['Q9ULW0', '5174.0'], dtype='<U10'),
#  array(['P31483', '5174.0'], dtype='<U10'),
#  array(['Q9Y3Z3', '5183.0'], dtype='<U10'),
#  array(['P00403', '5187.5'], dtype='<U10'),
#  array(['P14678', '5199.0'], dtype='<U10'),
#  array(['Q01085', '5199.0'], dtype='<U10'),
#  array(['P62854', '5206.0'], dtype='<U10'),
#  array(['Q9NR50', '5207.0'], dtype='<U10'),
#  array(['P46977', '5211.0'], dtype='<U10'),
#  array(['P14373', '5212.0'], dtype='<U10'),
#  array(['Q9H9E1', '5220.0'], dtype='<U10'),
#  array(['Q96ER3', '5225.0'], dtype='<U10'),
#  array(['Q9H0M0', '5226.0'], dtype='<U10'),
#  array(['Q53GQ0', '5229.0'], dtype='<U10'),
#  array(['P40763', '5230.0'], dtype='<U10'),
#  array(['O43504', '5235.0'], dtype='<U10'),
#  array(['Q86Y07', '5238.0'], dtype='<U10'),
#  array(['O15269', '5239.0'], dtype='<U10'),
#  array(['P32780', '5257.0'], dtype='<U10'),
#  array(['P11586', '5258.5'], dtype='<U10'),
#  array(['P18887', '5265.0'], dtype='<U10'),
#  array(['P36406', '5273.0'], dtype='<U10'),
#  array(['Q9UHA4', '5279.0'], dtype='<U10'),
#  array(['P18077', '5280.0'], dtype='<U10'),
#  array(['P18031', '5294.0'], dtype='<U10'),
#  array(['Q09161', '5303.0'], dtype='<U10'),
#  array(['P51572', '5304.0'], dtype='<U10'),
#  array(['P85037', '5309.0'], dtype='<U10'),
#  array(['P49589', '5312.0'], dtype='<U10'),
#  array(['O00232', '5331.0'], dtype='<U10'),
#  array(['Q9UBU9', '5344.5'], dtype='<U10'),
#  array(['P35606', '5353.0'], dtype='<U10'),
#  array(['Q9Y3B7', '5361.0'], dtype='<U10'),
#  array(['P46087', '5384.0'], dtype='<U10'),
#  array(['P78396', '5389.0'], dtype='<U10'),
#  array(['P46937', '5389.5'], dtype='<U10'),
#  array(['Q96IX5', '5391.0'], dtype='<U10'),
#  array(['Q8IXH7', '5400.5'], dtype='<U10'),
#  array(['Q13227', '5412.0'], dtype='<U10'),
#  array(['P48556', '5416.0'], dtype='<U10'),
#  array(['Q13618', '5431.0'], dtype='<U10'),
#  array(['P49069', '5440.0'], dtype='<U10'),
#  array(['Q96SI9', '5453.0'], dtype='<U10'),
#  array(['P55210', '5460.0'], dtype='<U10'),
#  array(['Q9H6F5', '5466.0'], dtype='<U10'),
#  array(['Q6DD88', '5472.0'], dtype='<U10'),
#  array(['P51784', '5473.0'], dtype='<U10'),
#  array(['Q96P50', '5478.0'], dtype='<U10'),
#  array(['Q9UBX5', '5484.0'], dtype='<U10'),
#  array(['P54577', '5494.5'], dtype='<U10'),
#  array(['Q01813', '5499.0'], dtype='<U10'),
#  array(['Q6NZI2', '5501.0'], dtype='<U10'),
#  array(['Q8IUH3', '5503.0'], dtype='<U10'),
#  array(['O15151', '5506.0'], dtype='<U10'),
#  array(['O15260', '5511.0'], dtype='<U10'),
#  array(['Q14151', '5512.0'], dtype='<U10'),
#  array(['Q9NR31', '5513.0'], dtype='<U10'),
#  array(['P45984', '5518.0'], dtype='<U10'),
#  array(['P54886', '5521.5'], dtype='<U10'),
#  array(['Q7L1Q6', '5530.0'], dtype='<U10'),
#  array(['P49459', '5532.0'], dtype='<U10'),
#  array(['Q969G3', '5534.0'], dtype='<U10'),
#  array(['Q16540', '5539.0'], dtype='<U10'),
#  array(['P01730', '5550.0'], dtype='<U10'),
#  array(['Q9BYD3', '5563.0'], dtype='<U10'),
#  array(['O43809', '5572.5'], dtype='<U10'),
#  array(['Q53EL6', '5596.0'], dtype='<U10'),
#  array(['P62491', '5598.0'], dtype='<U10'),
#  array(['O95232', '5600.0'], dtype='<U10'),
#  array(['P01009', '5602.0'], dtype='<U10'),
#  array(['P20618', '5602.5'], dtype='<U10'),
#  array(['Q9BXP5', '5605.0'], dtype='<U10'),
#  array(['Q13247', '5614.0'], dtype='<U10'),
#  array(['P28072', '5630.0'], dtype='<U10'),
#  array(['Q15029', '5632.0'], dtype='<U10'),
#  array(['Q07820', '5636.0'], dtype='<U10'),
#  array(['Q8WXA9', '5639.0'], dtype='<U10'),
#  array(['Q13243', '5646.0'], dtype='<U10'),
#  array(['Q5JVS0', '5647.0'], dtype='<U10'),
#  array(['Q86XP3', '5667.0'], dtype='<U10'),
#  array(['P10644', '5671.0'], dtype='<U10'),
#  array(['Q9UH99', '5675.0'], dtype='<U10'),
#  array(['O00487', '5688.0'], dtype='<U10'),
#  array(['Q9UDY4', '5691.0'], dtype='<U10'),
#  array(['O43290', '5701.5'], dtype='<U10'),
#  array(['Q9UN86', '5701.5'], dtype='<U10'),
#  array(['O00264', '5704.0'], dtype='<U10'),
#  array(['O14908', '5711.0'], dtype='<U10'),
#  array(['Q13107', '5717.0'], dtype='<U10'),
#  array(['P62140', '5722.5'], dtype='<U10'),
#  array(['Q7L5N1', '5725.0'], dtype='<U10'),
#  array(['P07195', '5729.0'], dtype='<U10'),
#  array(['P50502', '5736.0'], dtype='<U10'),
#  array(['P30048', '5746.0'], dtype='<U10'),
#  array(['P04075', '5749.5'], dtype='<U10'),
#  array(['P49588', '5751.0'], dtype='<U10'),
#  array(['Q96CX2', '5766.0'], dtype='<U10'),
#  array(['P33176', '5771.0'], dtype='<U10'),
#  array(['P98175', '5786.0'], dtype='<U10'),
#  array(['Q13492', '5797.0'], dtype='<U10'),
#  array(['P05556', '5800.0'], dtype='<U10'),
#  array(['Q9GZT3', '5803.0'], dtype='<U10'),
#  array(['P62318', '5806.0'], dtype='<U10'),
#  array(['Q9HAV7', '5817.5'], dtype='<U10'),
#  array(['Q96QV6', '5821.0'], dtype='<U10'),
#  array(['P19105', '5826.0'], dtype='<U10'),
#  array(['P46459', '5829.0'], dtype='<U10'),
#  array(['Q96GD4', '5831.0'], dtype='<U10'),
#  array(['Q15388', '5831.0'], dtype='<U10'),
#  array(['Q15773', '5835.0'], dtype='<U10'),
#  array(['O43791', '5838.0'], dtype='<U10'),
#  array(['P62495', '5842.0'], dtype='<U10'),
#  array(['O75934', '5845.0'], dtype='<U10'),
#  array(['O60260', '5846.0'], dtype='<U10'),
#  array(['Q8IY67', '5864.0'], dtype='<U10'),
#  array(['P83881', '5879.0'], dtype='<U10'),
#  array(['Q9BYD1', '5880.5'], dtype='<U10'),
#  array(['Q13405', '5883.5'], dtype='<U10'),
#  array(['Q9Y3D9', '5890.0'], dtype='<U10'),
#  array(['Q96DV4', '5894.0'], dtype='<U10'),
#  array(['Q9NRC8', '5914.0'], dtype='<U10'),
#  array(['P09234', '5920.0'], dtype='<U10'),
#  array(['P52434', '5926.0'], dtype='<U10'),
#  array(['O14828', '5928.0'], dtype='<U10'),
#  array(['P68032', '5935.0'], dtype='<U10'),
#  array(['O43264', '5939.0'], dtype='<U10'),
#  array(['O75955', '5941.0'], dtype='<U10'),
#  array(['P84090', '5957.5'], dtype='<U10'),
#  array(['B5ME19', '5961.5'], dtype='<U10'),
#  array(['Q13823', '5966.0'], dtype='<U10'),
#  array(['P49915', '5969.0'], dtype='<U10'),
#  array(['Q13451', '5981.0'], dtype='<U10'),
#  array(['Q92526', '5983.0'], dtype='<U10'),
#  array(['P82673', '5998.0'], dtype='<U10'),
#  array(['Q16576', '6005.0'], dtype='<U10'),
#  array(['P19827', '6006.0'], dtype='<U10'),
#  array(['O60783', '6014.0'], dtype='<U10'),
#  array(['P78406', '6017.0'], dtype='<U10'),
#  array(['Q9BRZ2', '6018.0'], dtype='<U10'),
#  array(['Q9H4B7', '6026.5'], dtype='<U10'),
#  array(['P0DP23', '6032.0'], dtype='<U10'),
#  array(['Q15050', '6034.0'], dtype='<U10'),
#  array(['Q9NZI8', '6054.0'], dtype='<U10'),
#  array(['P55081', '6059.0'], dtype='<U10'),
#  array(['P19320', '6068.0'], dtype='<U10'),
#  array(['P38432', '6082.0'], dtype='<U10'),
#  array(['Q15629', '6099.0'], dtype='<U10'),
#  array(['P17931', '6102.0'], dtype='<U10'),
#  array(['O75534', '6110.0'], dtype='<U10'),
#  array(['P82932', '6110.0'], dtype='<U10'),
#  array(['Q8N766', '6118.0'], dtype='<U10'),
#  array(['P48444', '6119.0'], dtype='<U10'),
#  array(['P52789', '6126.0'], dtype='<U10'),
#  array(['P18085', '6132.5'], dtype='<U10'),
#  array(['Q9BQ39', '6143.0'], dtype='<U10'),
#  array(['Q9Y2Q9', '6148.0'], dtype='<U10'),
#  array(['O00330', '6158.0'], dtype='<U10'),
#  array(['O00422', '6171.0'], dtype='<U10'),
#  array(['Q00688', '6186.0'], dtype='<U10'),
#  array(['Q9H9J2', '6187.0'], dtype='<U10'),
#  array(['Q15022', '6190.0'], dtype='<U10'),
#  array(['P52907', '6191.5'], dtype='<U10'),
#  array(['Q9BQ52', '6193.0'], dtype='<U10'),
#  array(['Q15003', '6198.0'], dtype='<U10'),
#  array(['Q92734', '6204.0'], dtype='<U10'),
#  array(['Q05519', '6210.5'], dtype='<U10'),
#  array(['Q02543', '6220.0'], dtype='<U10'),
#  array(['P35613', '6223.0'], dtype='<U10'),
#  array(['P29558', '6230.0'], dtype='<U10'),
#  array(['Q9HAU4', '6230.0'], dtype='<U10'),
#  array(['P04908', '6233.0'], dtype='<U10'),
#  array(['P11279', '6238.5'], dtype='<U10'),
#  array(['P58546', '6241.0'], dtype='<U10'),
#  array(['P31153', '6246.0'], dtype='<U10'),
#  array(['Q06481', '6249.0'], dtype='<U10'),
#  array(['Q562R1', '6255.0'], dtype='<U10'),
#  array(['O94776', '6268.5'], dtype='<U10'),
#  array(['Q96AE4', '6269.0'], dtype='<U10'),
#  array(['P68431', '6270.0'], dtype='<U10'),
#  array(['P20671', '6271.0'], dtype='<U10'),
#  array(['P11802', '6278.0'], dtype='<U10'),
#  array(['Q12834', '6279.5'], dtype='<U10'),
#  array(['Q99961', '6280.0'], dtype='<U10'),
#  array(['Q00534', '6281.0'], dtype='<U10'),
#  array(['P20290', '6281.0'], dtype='<U10'),
#  array(['Q9UJZ1', '6285.0'], dtype='<U10'),
#  array(['Q96HS1', '6287.0'], dtype='<U10'),
#  array(['P48729', '6292.0'], dtype='<U10'),
#  array(['Q9NZJ7', '6309.5'], dtype='<U10'),
#  array(['Q16082', '6319.0'], dtype='<U10'),
#  array(['Q9UBQ5', '6331.5'], dtype='<U10'),
#  array(['P13473', '6335.5'], dtype='<U10'),
#  array(['Q99661', '6376.0'], dtype='<U10'),
#  array(['P51571', '6390.0'], dtype='<U10'),
#  array(['Q15287', '6408.0'], dtype='<U10'),
#  array(['Q9Y6D9', '6409.0'], dtype='<U10'),
#  array(['P06241', '6413.0'], dtype='<U10'),
#  array(['P50416', '6417.5'], dtype='<U10'),
#  array(['Q13105', '6421.0'], dtype='<U10'),
#  array(['Q7Z417', '6426.5'], dtype='<U10'),
#  array(['Q96A33', '6427.0'], dtype='<U10'),
#  array(['P33240', '6429.0'], dtype='<U10'),
#  array(['Q9UKD2', '6439.0'], dtype='<U10'),
#  array(['Q96EZ8', '6452.0'], dtype='<U10'),
#  array(['P05771', '6454.0'], dtype='<U10'),
#  array(['P62820', '6455.0'], dtype='<U10'),
#  array(['P83436', '6456.0'], dtype='<U10'),
#  array(['Q9UBB4', '6463.0'], dtype='<U10'),
#  array(['P29353', '6464.0'], dtype='<U10'),
#  array(['P60953', '6466.0'], dtype='<U10'),
#  array(['Q8IXI1', '6472.5'], dtype='<U10'),
#  array(['P40337', '6476.0'], dtype='<U10'),
#  array(['O75027', '6479.0'], dtype='<U10'),
#  array(['Q9NZZ3', '6483.0'], dtype='<U10'),
#  array(['Q9HC07', '6492.5'], dtype='<U10'),
#  array(['P40692', '6505.5'], dtype='<U10'),
#  array(['Q9BRP8', '6507.0'], dtype='<U10'),
#  array(['P25963', '6517.0'], dtype='<U10'),
#  array(['Q5BKZ1', '6523.0'], dtype='<U10'),
#  array(['Q9UM11', '6529.0'], dtype='<U10'),
#  array(['P49406', '6530.0'], dtype='<U10'),
#  array(['Q9P031', '6531.5'], dtype='<U10'),
#  array(['Q9NY61', '6540.0'], dtype='<U10'),
#  array(['P51617', '6555.0'], dtype='<U10'),
#  array(['Q15434', '6558.0'], dtype='<U10'),
#  array(['P82914', '6564.0'], dtype='<U10'),
#  array(['Q9Y285', '6570.0'], dtype='<U10'),
#  array(['P63173', '6595.0'], dtype='<U10'),
#  array(['P33316', '6599.0'], dtype='<U10'),
#  array(['Q9Y512', '6602.0'], dtype='<U10'),
#  array(['Q96HC4', '6623.0'], dtype='<U10'),
#  array(['P28074', '6631.5'], dtype='<U10'),
#  array(['Q5C9Z4', '6632.0'], dtype='<U10'),
#  array(['Q13838', '6639.0'], dtype='<U10'),
#  array(['P62910', '6651.0'], dtype='<U10'),
#  array(['P12268', '6662.0'], dtype='<U10'),
#  ...]

# %%
ranks_sorted = np.array(hp_ranks_sorted[:,1], dtype=np.float)
rankOfRanks = rankdata(ranks_sorted)
index = np.where(hp_ranks_sorted[:,0] == "O00571")[0][0]
print(rankOfRanks[index])
# Out:
# 61.0

# %%
# Out:
# 61.0

# %%
for query in queries:
            index = np.where(hps == query)[0][0]
            rank = 16627 + 1 - ranks[index]
            queries[query].append(rank)
for query in queries:
    mean = np.mean(queries[query])
    print("%s\t%d\t%.3f\n" % (query, mean, mean/16627))
